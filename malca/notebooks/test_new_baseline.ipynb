dat3', '/home/calder/code/malca/output/runs/runs_march18_bundle_all/bundle_assets/lightcurves/137440070860.dat3', '/home/calder/code/malca/output/runs/runs_march18_bundle_all/bundle_assets/lightcurves/609885625944.dat3', '/home/calder/code/malca/output/runs/runs_march18_bundle_all/bundle_assets/lightcurves/214749686733.dat3', '/home/calder/code/malca/output/runs/runs_march18_bundle_all/bundle_assets/lightcurves/197569072833.dat3', '/home/calder/code/malca/output/runs/runs_march18_bundle_all/bundle_assets/lightcurves/549756905829.dat3', '/home/calder/code/malca/output/runs/runs_march18_bundle_all/bundle_assets/lightcurves/463856676332.dat3', '/home/calder/code/malca/output/runs/runs_march18_bundle_all/bundle_assets/lightcurves/446676964258.dat3', '/home/calder/code/malca/output/runs/runs_march18_bundle_all/bundle_assets/lightcurves/163209033637.dat3', '/home/calder/code/malca/output/runs/runs_march18_bundle_all/bundle_assets/lightcurves/60130640912.dat3']

for file in files:
    df = load_lightcurve_df(file)
    if df is None or len(df) == 0:
        continue
        
    df = per_camera_gp_baseline_masked(df)
    
    # Create 2x2 grid: Left=Pass1, Right=Pass2, Top=Main, Bottom=Residual
    fig, axes = plt.subplots(2, 2, figsize=(20, 10), sharex='col', gridspec_kw={'height_ratios': [3, 1]})
    fig.suptitle(f'Baseline for {Path(file).name}', y=0.95, fontsize=16)
    
    ax1_main = axes[0, 0]
    ax1_res = axes[1, 0]
    ax2_main = axes[0, 1]
    ax2_res = axes[1, 1]
    
    for cam, sub in df.groupby('camera#'):
        sub_sorted = sub.sort_values('JD')
        
        # Determine good/bad based on Pass 1's sigma_resid output
        good = (sub['sigma_resid'] <= GP_DIP_SIGMA_THRESH) & (sub['sigma_resid'] >= GP_BRIGHT_SIGMA_THRESH)
        bad = ~good
        
        # --- LEFT PANEL: Pass 1 (Stiff GP / Rough) ---
        # Plot good points normal, bad points RED
        ax1_main.errorbar(sub.loc[good, 'JD'], sub.loc[good, 'mag'], yerr=sub.loc[good, 'error'], 
                          fmt='.', alpha=0.3, label=f'Cam {cam} data')
        
        if bad.any():
            ax1_main.errorbar(sub.loc[bad, 'JD'], sub.loc[bad, 'mag'], yerr=sub.loc[bad, 'error'], 
                              fmt='x', color='red', alpha=0.7, label=f'Cam {cam} MASKED')
                     
        if 'base_rough' in sub.columns and not sub['base_rough'].isna().all():
            ax1_main.plot(sub_sorted['JD'], sub_sorted['base_rough'], '-', linewidth=2, label=f'Cam {cam} initial baseline')
            
            # Residuals against Pass 1 baseline
            ax1_res.errorbar(sub.loc[good, 'JD'], (sub['mag'] - sub['base_rough'])[good], yerr=sub.loc[good, 'error'], 
                             fmt='.', alpha=0.3)
            if bad.any():
                ax1_res.errorbar(sub.loc[bad, 'JD'], (sub['mag'] - sub['base_rough'])[bad], yerr=sub.loc[bad, 'error'], 
                                 fmt='x', color='red', alpha=0.7)
        else:
            print(f"Warning: No base_rough found for camera {cam} in {Path(file).name}")
        
        # --- RIGHT PANEL: Pass 2 (Flexible GP / Final) ---
        # Plot ALL points as normal (no red), showing how the final baseline looks against raw data
        ax2_main.errorbar(sub['JD'], sub['mag'], yerr=sub['error'], 
                          fmt='.', alpha=0.3, label=f'Cam {cam} data')
        
        # Residuals against final baseline (sub['resid'] is y - baseline for all points)
        ax2_res.errorbar(sub['JD'], sub['resid'], yerr=sub['error'], 
                         fmt='.', alpha=0.3)
        
        # Plot final baseline
        ax2_main.plot(sub_sorted['JD'], sub_sorted['baseline'], '-', linewidth=2, label=f'Cam {cam} final baseline')

    # Formatting Left Panel
    ax1_main.invert_yaxis()
    ax1_main.set_ylabel('Magnitude')
    ax1_main.set_title('Pass 1: Initial Stiff GP / Rough Baseline')
    ax1_main.legend()
    
    ax1_res.invert_yaxis() # Invert so "up" is brighter
    ax1_res.set_ylabel('Residual (mag)')
    ax1_res.set_xlabel('JD')
    ax1_res.axhline(0, color='black', linestyle='--', alpha=0.5)

    # Formatting Right Panel
    ax2_main.invert_yaxis()
    ax2_main.set_ylabel('Magnitude')
    ax2_main.set_title('Pass 2: Final Flexible GP Baseline')
    ax2_main.legend()
    
    ax2_res.invert_yaxis() # Invert so "up" is brighter
    ax2_res.set_ylabel('Residual (mag)')
    ax2_res.set_xlabel('JD')
    ax2_res.axhline(0, color='black', linestyle='--', alpha=0.5)
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# # Microlensing results — comprehensive EDA
#
# CSV from [`scripts/microlensing.py`](../../scripts/microlensing.py) → `output/microlensing/microlensing_results_<timestamp>.csv`.
#
# ### Column semantics
# - **`fit_t0`**: Paczyński display epoch when Paczyński is *selected*; often empty for `fred` / alt-model rows while **`fit_t0_jd_*`** still use the Paczyński fit.
# - **`reported_tE_days`**: Only when **`fit_ok`**; `raw_paczynski_tE_days` can still be finite when `fit_ok` is false.
# - **`display_raw_paczynski_tE_days`**: Cleared when selected model is not Paczyński.
# - Characterize adds many sparse columns — high NA rate is normal.

# %%
from __future__ import annotations

import re
from itertools import combinations
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D

plt.style.use("default")
pd.set_option("display.max_columns", 40)
pd.set_option("display.width", 120)
pd.set_option("display.float_format", lambda x: f"{x:.6g}" if pd.notna(x) else "")

# %%
# Repo root: directory with pyproject.toml
NOTEBOOK_DIR = Path.cwd()
for base in (NOTEBOOK_DIR, *NOTEBOOK_DIR.parents):
    if (base / "pyproject.toml").exists():
        REPO_ROOT = base.resolve()
        break
else:
    REPO_ROOT = NOTEBOOK_DIR.resolve()

MICROLENSING_DIR = REPO_ROOT / "output" / "microlensing"
CSV_PATH = None  # or Path("/path/to/microlensing_results_....csv")

if CSV_PATH is None:
    cand = sorted(MICROLENSING_DIR.glob("microlensing_results_*.csv"))
    if not cand:
        raise FileNotFoundError(
            f"No microlensing_results_*.csv under {MICROLENSING_DIR}. Set CSV_PATH."
        )
    CSV_PATH = cand[-1]
CSV_PATH = Path(CSV_PATH).expanduser().resolve()
print("REPO_ROOT:", REPO_ROOT)
print("CSV_PATH:", CSV_PATH)
# Out:
# REPO_ROOT: /home/calder/code/malca
# CSV_PATH: /home/calder/code/malca/output/microlensing/microlensing_results_20260325_131310.csv

# %%
df = pd.read_csv(CSV_PATH, low_memory=False)
print(f"shape: {df.shape[0]:,} rows × {df.shape[1]:,} cols")
# Out:
# shape: 112 rows × 387 cols

# %% [markdown]
# ### Schema snapshot
# `info()` memory estimate and which columns are numeric vs object.

# %%
df.info(verbose=False, memory_usage="deep")
print("dtypes:", df.dtypes.value_counts().to_dict())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112 entries, 0 to 111
# Columns: 387 entries, candidate_id to visual_inspection_subjective_note
# dtypes: bool(15), float64(301), int64(19), object(52)
# memory usage: 618.8 KB
# dtypes: {dtype('float64'): 301, dtype('O'): 52, dtype('int64'): 19, dtype('bool'): 15}

# %% [markdown]
# ### Correlation heatmap (numeric columns, finite pairs)
# Keeps up to 24 columns with most non-null numeric values.

# %%
num = df.select_dtypes(include=[np.number]).copy()
if num.shape[1] < 2:
    print("Not enough numeric columns for correlation")
else:
    counts = num.notna().sum().sort_values(ascending=False)
    keep = counts.head(min(24, len(counts))).index.tolist()
    sub = num[keep].dropna(how='all')
    if len(sub) > 5:
        c = sub.corr(min_periods=10)
        fig, ax = plt.subplots(figsize=(10, 8))
        im = ax.imshow(c.values, aspect='auto', cmap='RdBu_r', vmin=-1, vmax=1)
        ax.set_xticks(range(len(c.columns)))
        ax.set_yticks(range(len(c.columns)))
        ax.set_xticklabels(c.columns, rotation=90, fontsize=7)
        ax.set_yticklabels(c.columns, fontsize=7)
        plt.colorbar(im, ax=ax, fraction=0.046, label='Pearson r')
        ax.set_title(f'Correlation (n={len(sub)} rows, {len(keep)} cols)')
        plt.tight_layout()
        plt.show()
    else:
        print('Too few rows for correlation')

# %% [markdown]
# ## Helpers & column groups

# %%
def _num(s: pd.Series) -> pd.Series:
    return pd.to_numeric(s, errors="coerce")


def _booly(s: pd.Series) -> pd.Series:
    if getattr(s.dtype, "name", str(s.dtype)) == "bool":
        return s
    m = {
        "true": True,
        "false": False,
        "1": True,
        "0": False,
        1: True,
        0: False,
    }
    out = s.map(lambda x: m.get(x, x) if pd.notna(x) else np.nan)
    return out.astype("boolean")


def bundle_from_lc_path(p: object) -> str:
    if not isinstance(p, str) or not p:
        return "(missing)"
    m = re.search(r"/runs/([^/]+)/", p)
    return m.group(1) if m else "(no /runs/<bundle>/)"


KEY_ID = "candidate_id" if "candidate_id" in df.columns else df.columns[0]

df = df.copy()
if "lc_path" in df.columns:
    df["_bundle"] = df["lc_path"].map(bundle_from_lc_path)

prefix_sets = {}
for prefix in (
    "parallax_", "external_", "ogle_ews_220326_", "ogle_ews_", "kmtnet_", "moa_",
    "gaia_alert_", "asassn_ml_", "char_", "dust_", "unwise_", "erosita_", "tns_", "alerce_",
):
    cols = [c for c in df.columns if c.startswith(prefix)]
    if cols:
        key = prefix.rstrip("_")
        prefix_sets[key] = cols

print("Column groups by prefix:")
for k, cols in sorted(prefix_sets.items(), key=lambda kv: -len(kv[1])):
    print(f"  {k:28s} {len(cols):3d}")

all_na = [c for c in df.columns if df[c].isna().all()]
print(f"\nall-null columns: {len(all_na)}")
if len(all_na) <= 50:
    print(all_na)
elif all_na:
    print(all_na[:40], "...")

constant = [c for c in df.columns if df[c].nunique(dropna=False) <= 1]
print(f"\nconstant columns: {len(constant)}")
for c in constant[:30]:
    v = df[c].iloc[0] if len(df) else None
    print(f"  {c}: {v!r}")
# Out:
# Column groups by prefix:
#   parallax                      48
#   ogle_ews                      24
#   char                          24
#   external                      15
#   ogle_ews_220326               12
#   kmtnet                        12
#   moa                           12
#   unwise                         9
#   alerce                         6
#   gaia_alert                     5
#   tns                            4
#   asassn_ml                      3
#   dust                           2
#
# all-null columns: 125
# ['nearest_vsx_object', 'microlens_catalog', 'microlens_name', 'microlens_alt_name', 'microlens_te_days', 'microlens_sep_arcsec', 'ztf_var_type', 'period_lsp_best', 'period_lsp_power', 'period_pdm_best', 'period_pdm_theta', 'period_resid_lsp_best', 'period_resid_lsp_power', 'external_best_microlens_source', 'external_best_microlens_event_id', 'external_best_microlens_alias', 'external_best_microlens_sep_arcsec', 'external_best_microlens_catalog_t0_jd', 'external_best_microlens_catalog_t0_time_system', 'external_best_microlens_delta_t0_days', 'external_best_microlens_catalog_tE_days', 'external_best_microlens_catalog_tE_kind', 'external_best_microlens_delta_tE_days', 'external_best_microlens_delta_log_tE', 'external_best_microlens_status', 'external_best_microlens_event_year', 'external_best_microlens_source_url', 'ogle_ews_220326_event_id', 'ogle_ews_220326_alias', 'ogle_ews_220326_sep_arcsec', 'ogle_ews_220326_catalog_t0_jd', 'ogle_ews_220326_catalog_t0_time_system', 'ogle_ews_220326_delta_t0_days', 'ogle_ews_220326_catalog_tE_days', 'ogle_ews_220326_catalog_tE_kind', 'ogle_ews_220326_delta_tE_days', 'ogle_ews_220326_delta_log_tE', 'ogle_ews_220326_status', 'ogle_ews_220326_source_url', 'ogle_ews_event_id'] ...
#
# constant columns: 147
#   band_used: 'g'
#   seed_method: 'brightest10_median'
#   fit_t0_time_system: 'JD-2450000'
#   peak_window_time_system: 'JD-2450000'
#   paczynski_coverage_n_bins: 120
#   nearest_vsx_object: nan
#   microlens_match: False
#   microlens_catalog: nan
#   microlens_name: nan
#   microlens_alt_name: nan
#   microlens_te_days: nan
#   microlens_sep_arcsec: nan
#   ztf_var_type: nan
#   period_lsp_best: nan
#   period_lsp_power: nan
#   period_pdm_best: nan
#   period_pdm_theta: nan
#   period_resid_lsp_best: nan
#   period_resid_lsp_power: nan
#   periodicity_detected: False
#   external_best_microlens_source: nan
#   external_best_microlens_event_id: nan
#   external_best_microlens_alias: nan
#   external_best_microlens_sep_arcsec: nan
#   external_best_microlens_catalog_t0_jd: nan
#   external_best_microlens_catalog_t0_time_system: nan
#   external_best_microlens_delta_t0_days: nan
#   external_best_microlens_catalog_tE_days: nan
#   external_best_microlens_catalog_tE_kind: nan
#   external_best_microlens_delta_tE_days: nan

# %% [markdown]
# ## Executive summary

# %%
n = len(df)
print(f"N = {n:,}  duplicate {KEY_ID}: {int(df[KEY_ID].duplicated().sum())}")

if "_bundle" in df.columns:
    print("\nRows per bundle (from lc_path):")
    display(df["_bundle"].value_counts().to_frame("n"))

if "fit_ok" in df.columns:
    ok = _booly(df["fit_ok"]).fillna(False)
    print(f"\nfit_ok rate: {ok.mean():.3f} ({ok.sum():,} / {n:,})")

if "best_model" in df.columns:
    print("\nbest_model:")
    display(df["best_model"].value_counts(dropna=False).to_frame("n"))
if "selection_mode" in df.columns:
    print("\nselection_mode:")
    display(df["selection_mode"].value_counts(dropna=False).to_frame("n"))

for col in (
    "parallax_attempted", "parallax_fit_ok", "parallax_preferred",
    "external_known_microlens", "microlens_match", "vetting_likely_known",
):
    if col not in df.columns:
        continue
    s = df[col]
    if s.dtype == object or str(s.dtype) in ("boolean", "bool"):
        vc = s.value_counts(dropna=False)
    else:
        vc = _booly(s).value_counts(dropna=False)
    print(f"\n{col}:")
    display(vc.to_frame("n"))
# Out:
# N = 112  duplicate candidate_id: 0
#
# Rows per bundle (from lc_path):
#                                             n
# _bundle
# output_bundle_13.5_14_bundle_13.5_14       25
# runs_march18_bundle_all                    23
# output_bundle_14_14.5_bundle_14_14.5       23
# output_bundle_13_13.5_bundle_13_13.5       20
# output_bundle_12_12.5_home_bundle_12_12.5  11
# output_bundle_12.5_13_home_bundle_12.5_13  10
# fit_ok rate: 0.205 (23 / 112)
#
# best_model:
#              n
# best_model
# fred        57
# paczynski   55
# selection_mode:
#                         n
# selection_mode
# significant_alt_model  57
# fallback_paczynski     32
# paczynski_qc           23
# parallax_attempted:
#                      n
# parallax_attempted
# False               70
# True                42
# parallax_fit_ok:
#                   n
# parallax_fit_ok
# False            85
# True             27
# parallax_preferred:
#                      n
# parallax_preferred
# False               86
# True                26
# external_known_microlens:
#                            n
# external_known_microlens
# <NA>                      93
# False                     18
# True                       1
# microlens_match:
#                    n
# microlens_match
# False            112
# vetting_likely_known:
#                        n
# vetting_likely_known
# False                 66
# True                  46

# %% [markdown]
# ## Model selection — crosstabs & BIC disagreements

# %%
if {"selection_mode", "best_model"}.issubset(df.columns):
    display(pd.crosstab(df["selection_mode"], df["best_model"], margins=True))

if {"best_model", "best_model_by_bic"}.issubset(df.columns):
    msel = df["best_model"].astype(str)
    mbic = df["best_model_by_bic"].astype(str)
    dis = msel.notna() & mbic.notna() & (msel != "nan") & (mbic != "nan") & (msel != mbic)
    print(f"best_model != best_model_by_bic: {dis.sum()} / {len(df)}")
    if dis.any():
        cols = [c for c in (KEY_ID, "selection_mode", "best_model", "best_model_by_bic", "best_alt_model", "fit_ok") if c in df.columns]
        display(df.loc[dis, cols].head(50))
# Out:
# best_model             fred  paczynski  All
# selection_mode
# fallback_paczynski        0         32   32
# paczynski_qc              0         23   23
# significant_alt_model    57          0   57
# All                      57         55  112
# best_model != best_model_by_bic: 47 / 112
#      candidate_id         selection_mode best_model best_model_by_bic best_alt_model  fit_ok
# 0    103079263205           paczynski_qc  paczynski          gaussian       gaussian    True
# 1    120259784233     fallback_paczynski  paczynski          gaussian       gaussian   False
# 3    188979054063     fallback_paczynski  paczynski          gaussian       gaussian   False
# 4     25771219762           paczynski_qc  paczynski          gaussian       gaussian    True
# 6     34360800532     fallback_paczynski  paczynski              fred           fred   False
# 7    472447489028           paczynski_qc  paczynski          gaussian       gaussian    True
# 10   541166175153           paczynski_qc  paczynski          gaussian       gaussian    True
# 11   566936418537           paczynski_qc  paczynski          gaussian       gaussian    True
# 13   609886176748     fallback_paczynski  paczynski          gaussian       gaussian   False
# 14   618475317371           paczynski_qc  paczynski          gaussian       gaussian    True
# 15   627065322644           paczynski_qc  paczynski          gaussian       gaussian    True
# 18    77310050643  significant_alt_model       fred          gaussian       gaussian   False
# 20   163208971697     fallback_paczynski  paczynski          gaussian       gaussian   False
# 22   188979615172           paczynski_qc  paczynski          gaussian       gaussian    True
# 23   309237796027           paczynski_qc  paczynski          gaussian       gaussian    True
# 27   566936418698           paczynski_qc  paczynski          gaussian       gaussian    True
# 29   120260181420     fallback_paczynski  paczynski          gaussian       gaussian   False
# 34   489626666467  significant_alt_model       fred          gaussian       gaussian   False
# 35   506806257773     fallback_paczynski  paczynski          gaussian       gaussian   False
# 37   584116544153           paczynski_qc  paczynski          gaussian       gaussian    True
# 39    85899644125     fallback_paczynski  paczynski          gaussian       gaussian   False
# 42   154619125882     fallback_paczynski  paczynski          gaussian       gaussian   False
# 44   171799069048           paczynski_qc  paczynski          gaussian       gaussian    True
# 45   206158789308           paczynski_qc  paczynski          gaussian       gaussian    True
# 47   249108525273  significant_alt_model       fred          gaussian       gaussian   False
# 49   283468880065     fallback_paczynski  paczynski          gaussian       gaussian   False
# 50   300648731140     fallback_paczynski  paczynski          gaussian       gaussian   False
# 51   326418144856           paczynski_qc  paczynski          gaussian       gaussian    True
# 53   420907148899           paczynski_qc  paczynski          gaussian       gaussian    True
# 54   438086781615     fallback_paczynski  paczynski          gaussian       gaussian   False
# 57   549756255044     fallback_paczynski  paczynski          gaussian       gaussian   False
# 58   549756685262     fallback_paczynski  paczynski          gaussian       gaussian   False
# 60   584116541991     fallback_paczynski  paczynski          gaussian       gaussian   False
# 61   584116581240     fallback_paczynski  paczynski          gaussian       gaussian   False
# 66   128849212363     fallback_paczynski  paczynski          gaussian       gaussian   False
# 69   274878446794           paczynski_qc  paczynski          gaussian       gaussian    True
# 70   292058312587     fallback_paczynski  paczynski          gaussian       gaussian   False
# 73   377957380524           paczynski_qc  paczynski          gaussian       gaussian    True
# 84    77310544110     fallback_paczynski  paczynski          gaussian       gaussian   False
# 91   180388979292  significant_alt_model       fred          gaussian       gaussian   False
# 92   292058411251     fallback_paczynski  paczynski          gaussian       gaussian   False
# 96   343598271892     fallback_paczynski  paczynski          gaussian       gaussian   False
# 99   377957176259  significant_alt_model       fred          gaussian       gaussian   False
# 102  438087177121     fallback_paczynski  paczynski          gaussian       gaussian   False
# 104  541166355079     fallback_paczynski  paczynski          gaussian       gaussian   False
# 106        559303     fallback_paczynski  paczynski          gaussian       gaussian   False
# 110   77310672808           paczynski_qc  paczynski          gaussian       gaussian    True

# %% [markdown]
# ## Fit quality — χ², ΔBIC, window

# %%
chi_cols = [c for c in ("paczynski_reduced_chi2", "fit_reduced_chi2") if c in df.columns]
if chi_cols:
    display(df[chi_cols].apply(_num).describe(percentiles=[0.25, 0.5, 0.75, 0.9, 0.99]).T)

bic_cols = [c for c in df.columns if c.startswith("delta_bic_vs_")]
if bic_cols:
    display(df[bic_cols].apply(_num).describe(percentiles=[0.05, 0.5, 0.95]).T)

aux = [c for c in ("n_points_fit", "half_window_days", "shoulder_left", "shoulder_right", "n_strong_points") if c in df.columns]
if aux:
    display(df[aux].apply(_num).describe().T)
# Out:
#                         count    mean     std     min     25%     50%     75%     90%     99%     max
# paczynski_reduced_chi2    112 10.4206 10.8302 1.55211 4.48166 7.29307 10.0494 24.9188 58.1119 60.9144
# fit_reduced_chi2          112 9.19749 8.65791 1.35762 4.33341 7.14522 9.46287 21.4657 44.0917 58.8756
#                        count     mean     std      min       5%      50%     95%     max
# delta_bic_vs_flat        112  28958.4 58527.4  2057.62  3887.68  14474.5 82190.8  509734
# delta_bic_vs_gaussian    112  5112.64 48284.9 -3212.77 -873.696 -117.557 3618.73  509754
# delta_bic_vs_fred        112  185.062 7138.95 -20195.8 -2604.98 -9.85756 1237.23 70277.3
# delta_bic_vs_best_alt    112 -856.503 2276.99 -20195.8 -3070.98 -334.792 105.441  1838.7
#                   count    mean     std     min     25%   50%    75%  max
# n_points_fit        112  810.58 409.274     148   545.5 740.5 903.25 2283
# half_window_days    112 1703.43  646.62 339.421 1119.63  2200   2200 2200
# shoulder_left       112 91.7054 88.9458       1   30.75  62.5 122.75  480
# shoulder_right      112 87.5268 77.5934       1      29    67 119.25  441
# n_strong_points     112 109.759 73.0663      10   53.75    96  146.5  336

# %%
def _trim_chi(s: pd.Series) -> np.ndarray:
    x = _num(s).replace([np.inf, -np.inf], np.nan).dropna().to_numpy()
    x = x[x > 0]
    if len(x) < 5:
        return x
    return x[x <= np.nanpercentile(x, 99)]


fig, axes = plt.subplots(1, 2, figsize=(11, 4))
for ax, col in zip(axes, ("paczynski_reduced_chi2", "fit_reduced_chi2")):
    if col not in df.columns:
        ax.set_title(f"{col} — missing")
        continue
    x = _trim_chi(df[col])
    if len(x):
        ax.hist(x, bins=40, color="steelblue", edgecolor="white")
    ax.set_title(col + " (99th pct clip)")
    ax.set_xlabel("reduced χ²")
plt.tight_layout()
plt.show()

# %%
if "fit_reduced_chi2" in df.columns and "selection_mode" in df.columns:
    sub = df.assign(_chi=_num(df["fit_reduced_chi2"]), _mode=df["selection_mode"])
    modes = sub["_mode"].value_counts().head(8).index.tolist()
    parts, labels = [], []
    for m in modes:
        p = sub.loc[sub["_mode"] == m, "_chi"].dropna()
        p = p.replace([np.inf, -np.inf], np.nan).dropna()
        p = p[(p > 0)]
        if len(p) > 10:
            hi = np.nanpercentile(p, 98)
            p = p[p <= hi]
        if len(p):
            parts.append(p.to_numpy())
            labels.append(str(m))
    if parts:
        fig, ax = plt.subplots(figsize=(10, 4.5))
        ax.boxplot(parts, vert=True)
        ax.set_xticklabels(labels, rotation=22, ha="right")
        ax.set_ylabel("fit_reduced_chi2 (per-mode 98% clip)")
        ax.set_title("Reduced χ² by selection_mode")
        plt.xticks(rotation=22, ha="right")
        plt.tight_layout()
        plt.show()

# %% [markdown]
# ## Timescales

# %%
rte = _num(df["reported_tE_days"]) if "reported_tE_days" in df.columns else None
rawte = _num(df["raw_paczynski_tE_days"]) if "raw_paczynski_tE_days" in df.columns else None
dpte = _num(df["display_raw_paczynski_tE_days"]) if "display_raw_paczynski_tE_days" in df.columns else None

if rte is not None and rawte is not None:
    ok_mask = _booly(df["fit_ok"]).fillna(False) if "fit_ok" in df.columns else pd.Series(True, index=df.index)
    both = ok_mask & rte.notna() & rawte.notna()
    if both.sum():
        rel = (rte[both] - rawte[both]).abs() / rawte[both].replace(0, np.nan)
        print(f"fit_ok & finite t_E: max relative |reported-raw|/raw = {float(rel.max()):.6g}")
    m = rte.notna() & rawte.notna() & (rawte > 0) & (rte > 0)
    fig, ax = plt.subplots(figsize=(5.5, 5.5))
    if m.any():
        fk = _booly(df["fit_ok"]).fillna(False) if "fit_ok" in df.columns else pd.Series(False, index=df.index)
        ax.scatter(rawte[m], rte[m], c=np.where(fk[m], "tab:blue", "tab:red"), s=12, alpha=0.5)
        lo = float(min(rawte[m].min(), rte[m].min()))
        hi = float(max(rawte[m].max(), rte[m].max()))
        ax.plot([lo, hi], [lo, hi], "k--", lw=1, alpha=0.5)
    ax.set_xlabel("raw_paczynski_tE_days")
    ax.set_ylabel("reported_tE_days")
    ax.set_title("t_E (blue=fit_ok)")
    ax.legend(handles=[
        Line2D([0], [0], marker="o", color="w", markerfacecolor="tab:blue", linestyle="", label="fit_ok"),
        Line2D([0], [0], marker="o", color="w", markerfacecolor="tab:red", linestyle="", label="not fit_ok"),
    ])
    plt.tight_layout()
    plt.show()

for col, lab in ((rte, "reported_tE_days"), (rawte, "raw_paczynski_tE_days"), (dpte, "display_raw_paczynski_tE_days")):
    if col is None:
        continue
    x = col.replace([np.inf, -np.inf], np.nan).dropna()
    x = x[x > 0]
    if len(x) < 2:
        continue
    fig, ax = plt.subplots(figsize=(6, 3.5))
    ax.hist(x, bins=32, color="darkseagreen", edgecolor="white")
    ax.set_xlabel(f"{lab} (days)")
    plt.title(lab)
    plt.tight_layout()
    plt.show()
# Out:
# fit_ok & finite t_E: max relative |reported-raw|/raw = 0

# %% [markdown]
# ## Seeds & epochs

# %%
if {"seed_t0_guess", "fit_t0_jd_minus_2450000"}.issubset(df.columns):
    a, b = _num(df["seed_t0_guess"]), _num(df["fit_t0_jd_minus_2450000"])
    m = a.notna() & b.notna()
    if m.sum():
        fig, ax = plt.subplots(figsize=(5.5, 5.5))
        ax.scatter(a[m], b[m], s=10, alpha=0.45, c="tab:purple")
        lo = float(np.nanpercentile(np.r_[a[m], b[m]], 1))
        hi = float(np.nanpercentile(np.r_[a[m], b[m]], 99))
        ax.plot([lo, hi], [lo, hi], "k--", lw=1)
        ax.set_xlabel("seed_t0_guess")
        ax.set_ylabel("fit_t0_jd_minus_2450000 (Pacz)")
        ax.set_title("Seed vs Paczyński t0")
        plt.tight_layout()
        plt.show()

if {"pipeline_jump_t0", "seed_t0_guess"}.issubset(df.columns):
    pj, sg = _num(df["pipeline_jump_t0"]), _num(df["seed_t0_guess"])
    m = pj.notna() & sg.notna()
    if m.sum() > 5:
        fig, ax = plt.subplots(figsize=(6, 4))
        ax.scatter(pj[m], sg[m], s=10, alpha=0.45)
        ax.set_xlabel("pipeline_jump_t0")
        ax.set_ylabel("seed_t0_guess")
        plt.title("Jump vs seed t0")
        plt.tight_layout()
        plt.show()

if "seed_method" in df.columns:
    display(df["seed_method"].value_counts(dropna=False).to_frame("n"))
# Out:
#                       n
# seed_method
# brightest10_median  112

# %% [markdown]
# ## ΔBIC scatter

# %%
if {"delta_bic_vs_flat", "delta_bic_vs_gaussian"}.issubset(df.columns):
    x = _num(df["delta_bic_vs_flat"])
    y = _num(df["delta_bic_vs_gaussian"])
    m = np.isfinite(x) & np.isfinite(y)
    if m.sum():
        fig, ax = plt.subplots(figsize=(6.5, 5.5))
        ax.scatter(x[m], y[m], s=12, alpha=0.45, c="tab:blue")
        ax.axvline(0, color="k", lw=0.8, ls="--")
        ax.axhline(0, color="k", lw=0.8, ls="--")
        ax.set_xlabel("ΔBIC vs flat")
        ax.set_ylabel("ΔBIC vs gaussian")
        plt.title("BIC margins (best seed)")
        plt.tight_layout()
        plt.show()

if "delta_bic_vs_flat" in df.columns:
    d = _num(df["delta_bic_vs_flat"])
    thr = 100.0
    strong = d > thr
    print(f"delta_bic_vs_flat > {thr}: {int(strong.sum())}")
    if strong.any():
        cols = [c for c in (KEY_ID, "best_model", "fit_ok", "paczynski_reduced_chi2", "reported_tE_days", "delta_bic_vs_flat") if c in df.columns]
        display(df.loc[strong, cols].sort_values("delta_bic_vs_flat", ascending=False).head(25))
# Out:
# delta_bic_vs_flat > 100.0: 112
#      candidate_id best_model  fit_ok  paczynski_reduced_chi2  reported_tE_days  delta_bic_vs_flat
# 12   575525833425       fred   False                  23.618               NaN             509734
# 57   549756255044  paczynski   False                 28.1294               NaN             253442
# 1    120259784233  paczynski   False                 28.3005               NaN             239718
# 94   317828552480       fred   False                   9.741               NaN             133561
# 48   257698235806       fred   False                 60.9144               NaN            96874.8
# 71   300648519238       fred   False                 58.7592               NaN            83404.4
# 21   188979391597       fred   False                 8.63309               NaN            81197.8
# 29   120260181420  paczynski   False                  7.1605               NaN            59307.7
# 79   575526671022       fred   False                 8.64032               NaN            58511.4
# 74   386547890812       fred   False                 10.0471               NaN            52876.9
# 41   146029437956       fred   False                 15.0779               NaN            52348.3
# 13   609886176748  paczynski   False                 7.73123               NaN            47427.1
# 35   506806257773  paczynski   False                 9.16798               NaN            46806.3
# 63   635655307328  paczynski   False                 7.33021               NaN            45459.9
# 47   249108525273       fred   False                 9.80437               NaN            42127.2
# 34   489626666467       fred   False                 5.08683               NaN            41951.9
# 55   523987126282       fred   False                 27.6766               NaN            40547.3
# 86   377957887531       fred   False                 7.49959               NaN            39644.3
# 54   438086781615  paczynski   False                 8.63773               NaN            38050.9
# 15   627065322644  paczynski    True                 4.54066           143.161            37114.3
# 3    188979054063  paczynski   False                 7.15443               NaN              34891
# 77   523987048485       fred   False                 9.25479               NaN            32376.4
# 46   223339461587  paczynski   False                 7.74092               NaN            31696.1
# 4     25771219762  paczynski    True                 4.48232           142.868              31411
# 103  472447177813       fred   False                 13.4588               NaN            30083.3

# %% [markdown]
# ## Parallax

# %%
pcols = [c for c in df.columns if c.startswith("parallax_")]
if not pcols:
    print("No parallax_* columns")
else:
    if "parallax_status" in df.columns:
        display(df["parallax_status"].value_counts(dropna=False).to_frame("n"))
    keyn = [
        c for c in pcols
        if any(k in c for k in ("_tE_days", "chi2", "_bic", "piE", "_u0", "acceptance", "_samples"))
        and c not in ("parallax_warning",)
    ]
    keyn = [c for c in keyn if c in df.columns][:32]
    if keyn:
        display(df[keyn].apply(_num).describe(percentiles=[0.5, 0.9]).T)

if {"parallax_best_tE_days", "raw_paczynski_tE_days"}.issubset(df.columns):
    a, b = _num(df["parallax_best_tE_days"]), _num(df["raw_paczynski_tE_days"])
    m = a.notna() & b.notna() & (a > 0) & (b > 0)
    if m.sum() > 3:
        fig, ax = plt.subplots(figsize=(5.5, 5.5))
        ax.scatter(b[m], a[m], s=14, alpha=0.5)
        lo = float(min(b[m].min(), a[m].min()))
        hi = float(max(b[m].max(), a[m].max()))
        ax.plot([lo, hi], [lo, hi], "k--", lw=1)
        ax.set_xlabel("raw_paczynski_tE_days")
        ax.set_ylabel("parallax_best_tE_days")
        plt.title("Parallax vs PSPL t_E")
        plt.tight_layout()
        plt.show()
# Out:
#                                              n
# parallax_status
# not_attempted:selected_model_not_paczynski  57
# preferred                                   26
# fit_unreliable                              15
# not_attempted:tE_below_threshold            13
# fit_ok                                       1
#                                  count       mean       std         min         50%       90%      max
# parallax_pspl_flux_chi2             42    8774.65   10748.3     1609.57     5168.32   18879.9  59032.4
# parallax_pspl_flux_bic              42       8808   10749.4     1641.86     5201.17   18913.5  59071.1
# parallax_pspl_flux_reduced_chi2     42    9.70314   8.80213     2.54277     7.08572   23.6086  47.1724
# parallax_delta_bic                  42    1226.84   3797.15    -3.59223     381.969   1425.25  24739.6
# parallax_branch_delta_bic           42      607.4   2703.29      4.0292     114.272   541.825  17663.1
# parallax_best_tE_days               42    219.749   149.697     47.5421     180.087   369.388   819.31
# parallax_best_u0                    42 -0.0623799   1.16957    -1.60397   -0.308847   1.45872  1.58113
# parallax_best_piE_N                 42 -0.0988074   0.37606        -1.5   0.0127758  0.240374 0.336227
# parallax_best_piE_E                 42 -0.0327967  0.319194    -0.98892  0.00503768  0.340491 0.468527
# parallax_best_piE                   42   0.385363  0.319815   0.0177309    0.331838  0.756266  1.79665
# parallax_best_chi2                  42    7534.46   8274.04     1447.33     4798.17   17905.6  39645.1
# parallax_best_reduced_chi2          42    8.65002   8.37402     2.50187     6.06285   19.3366  46.7965
# parallax_best_bic                   42    7581.16   8275.46     1488.91     4845.51   17952.7  39696.5
# parallax_best_acceptance_rate       42  0.0847619 0.0774589 0.000833333   0.0572222  0.214056 0.269444
# parallax_best_n_samples            112        450   583.559           0           0      1200     1200
# parallax_pos_tE_days                42     211.67   142.547     48.8529     166.103   366.156   819.31
# parallax_pos_u0                     42    1.04607  0.418051        0.05     1.18312   1.47315  1.58113
# parallax_pos_piE_N                  42 -0.0235571  0.371047   -0.933398 -0.00100333   0.23752      1.5
# parallax_pos_piE_E                  42 0.00191483   0.33488   -0.642627  -0.0550381  0.337428      1.5
# parallax_pos_piE                    42   0.337792  0.365384   0.0177309    0.249152   0.71608  2.12132
# parallax_pos_chi2                   42    8074.58    9943.8     1503.41     4927.56     18205  51940.5
# parallax_pos_reduced_chi2           42    9.00549    8.6408     2.51813     6.06285   21.9556  46.8553
# parallax_pos_bic                    42    8121.27   9945.29     1545.21      4974.9   18252.1  51994.6
# parallax_pos_acceptance_rate        42  0.0943585 0.0893552  0.00194444   0.0601389  0.214056 0.420278
# parallax_pos_n_samples             112        450   583.559           0           0      1200     1200
# parallax_neg_tE_days                42    246.258   197.244     47.5421     189.253   426.968  1239.76
# parallax_neg_u0                     42   -1.01829  0.457596    -1.60397    -1.18682 -0.433082   -0.001
# parallax_neg_piE_N                  42 -0.0671542  0.335766        -1.5   0.0127758  0.229458  0.70114
# parallax_neg_piE_E                  42 -0.0135869  0.313336    -0.98892   0.0416177   0.33943 0.424156
# parallax_neg_piE                    42   0.359218  0.289037   0.0290301    0.321468   0.54302  1.79665
# parallax_neg_chi2                   42    7595.23   8259.94     1447.33     4798.17   17905.6  39645.1
# parallax_neg_reduced_chi2           42    8.71455   8.34666     2.50187     6.45367   19.3366  46.7965

# %% [markdown]
# ## External catalog & surveys

# %%
if "external_known_microlens" in df.columns:
    ext = _booly(df["external_known_microlens"]).fillna(False)
    print(f"external_known_microlens: {int(ext.sum())} / {len(df)}")
    if ext.any():
        ecols = [c for c in df.columns if c.startswith("external_best_microlens")]
        display(df.loc[ext, [KEY_ID] + ecols].head(25))
    if ext.any() and "external_best_microlens_delta_t0_days" in df.columns:
        d0 = _num(df.loc[ext, "external_best_microlens_delta_t0_days"]).dropna()
        if len(d0):
            fig, ax = plt.subplots(figsize=(5, 3.5))
            ax.hist(np.log10(d0.clip(lower=1e-6)), bins=25, color="coral", edgecolor="white")
            ax.set_xlabel("log10(Δt0 days) vs external catalog")
            plt.title("External microlens time residuals")
            plt.tight_layout()
            plt.show()

for col, lab in (
    ("ogle_ews_event_id", "OGLE EWS"),
    ("ogle_ews_220326_event_id", "OGLE 220326"),
    ("kmtnet_event_id", "KMTNet"),
    ("moa_event_id", "MOA"),
):
    if col not in df.columns:
        continue
    nn = df[col].notna() & (df[col].astype(str).str.strip().str.len() > 0)
    print(f"{lab}: {int(nn.sum())} with {col}")
# Out:
# external_known_microlens: 1 / 112
#    candidate_id  external_best_microlens_source  external_best_microlens_event_id  external_best_microlens_alias  \
# 1  120259784233                             NaN                               NaN                            NaN
#
#    external_best_microlens_sep_arcsec  external_best_microlens_catalog_t0_jd  \
# 1                                 NaN                                    NaN
#
#    external_best_microlens_catalog_t0_time_system  external_best_microlens_delta_t0_days  \
# 1                                             NaN                                    NaN
#
#    external_best_microlens_catalog_tE_days  external_best_microlens_catalog_tE_kind  \
# 1                                      NaN                                      NaN
#
#    external_best_microlens_delta_tE_days  external_best_microlens_delta_log_tE  external_best_microlens_status  \
# 1                                    NaN                                   NaN                             NaN
#
#    external_best_microlens_event_year  external_best_microlens_source_url
# 1                                 NaN                                 NaN
# OGLE EWS: 0 with ogle_ews_event_id
# OGLE 220326: 0 with ogle_ews_220326_event_id
# KMTNet: 0 with kmtnet_event_id
# MOA: 0 with moa_event_id

# %% [markdown]
# ## SIMBAD / VSX / Gaia / ZTF

# %%
for col, topn in (
    ("simbad_otype", 25),
    ("vsx_class", 20),
    ("gaia_var_class", 20),
    ("ztf_var_type", 20),
    ("catalog_source", 15),
):
    if col not in df.columns:
        continue
    print(f"\n{col} (top {topn}):")
    display(df[col].astype(str).value_counts(dropna=False).head(topn).to_frame("n"))

if "asassn_ml_match" in df.columns:
    display(df["asassn_ml_match"].value_counts(dropna=False).to_frame("n"))
if "gaia_alert_lookup_status" in df.columns:
    display(df["gaia_alert_lookup_status"].value_counts(dropna=False).to_frame("n"))
if "gaia_alert_microlens_like" in df.columns:
    display(_booly(df["gaia_alert_microlens_like"]).value_counts(dropna=False).to_frame("n"))
# Out:
# simbad_otype (top 25):
#                n
# simbad_otype
# nan           62
# *             24
# Em*           11
# V*             2
# ev             2
# gD*            2
# SB*            1
# EB*            1
# Be*            1
# cC*            1
# Y*O            1
# Sy*            1
# Be?            1
# HXB            1
# Pu*            1
# vsx_class (top 20):
#             n
# vsx_class
# nan        88
# VAR        17
# CST         2
# GCAS:       2
# Microlens   1
# VAR:        1
# ZAND        1
# gaia_var_class (top 20):
#                   n
# gaia_var_class
# nan              90
# DSCT|GDOR|SXPHE  11
# RS                8
# YSO               1
# SYST              1
# BE|GCAS|SDOR|WR   1
# ztf_var_type (top 20):
#                 n
# ztf_var_type
# nan           112
# catalog_source (top 15):
#                   n
# catalog_source
# nan             105
# asassn_var        5
# vsx               2
#                   n
# asassn_ml_match
# NaN              93
# 0                18
# 1                 1
#                            n
# gaia_alert_lookup_status
# NaN                       93
# queried                   19
#                             n
# gaia_alert_microlens_like
# <NA>                       93
# False                      19

# %% [markdown]
# ## Catalog & module reference (`--crossmatch`)
#
#
#
# When **`scripts/microlensing.py`** runs with **`--crossmatch`**, enrichment is mainly:
#
#
#
# 1. **`malca.characterize.characterize_candidates_df`** — Gaia multi-wavelength context, VSX crossmatch, optional BANYAN Σ, IPHAS, nearest **star-forming regions**, **open clusters**, unWISE/unTimely, **3D dust** (`A_v_3d` / `ebv_3d`), StarHorse, etc.
#
# 2. **`malca.vetting.vet_candidates`** — **post-review vetting** (what the log calls `POST-REVIEW VETTING`). That step is the one that prints the **VETTING SUMMARY** block.
#
#
#
# **Vetting (`vet_candidates`) — complete list of catalog / checks** (all that can appear in the summary; each may be skipped if toggled off or if prerequisites are missing):
#
#
#
# - **SIMBAD** — CDS XMatch → `nearest_simbad_object`, `simbad_otype`, `simbad_sep_arcsec`, …
#
# - **Gaia DR3 variability** — `vari_summary` / classifier → Gaia var columns (e.g. `gaia_var_class`)
#
# - **Gaia epoch photometry** — per-source epoch stats (vetting adds time-series-related fields)
#
# - **ASAS-SN variable catalog** (TAP) → `asassn_var_name`, `asassn_var_type`, …
#
# - **ZTF variables** (TAP) → `ztf_var_type`, …
#
# - **TNS** — only if local `input/tns_public_objects.csv` / `input/tns_sne.csv` are loaded → `tns_name`, …
#
# - **Gaia EB parameters** — only for ECL-classified Gaia sources in that vetting path
#
# - **ALeRCE** (ZTF broker) → e.g. `alerce_lc_class`, …
#
# - **eROSITA** X-ray crossmatch → `xray_det`, `xray_flux`, `xray_sep_arcsec`
#
# - **PM consistency** — proper motion vs. open-cluster mean when `cluster_name` / membership justify it → `pm_cluster_offset_sigma`
#
#
#
# **`vetting_likely_known`** is computed at the end of vetting from combinations of the above (plus microlens matches, etc.); see `malca/vetting.py` near the “Likely known” printout.
#
#
#
# **Not part of that vetting block:** the script’s separate **published microlensing event** crossmatch (`external_*`, `ogle_*`, `kmtnet_*`, `moa_*`) and optional **Gaia Alerts** table — merged later in `microlensing.py`.
#
# The **terminal** block under `VETTING SUMMARY` (match counts per module, `Likely known` / `Potentially new`) is the authoritative checklist for that run; modules print “skipping” when inputs are missing (e.g. TNS CSVs, ECL Gaia sources, enough cluster members for PM).

# %% [markdown]
# ## Astronomy: known variables & catalog provenance
#
# After **`vet_candidates`**, **`vetting_likely_known`** is true if any archival indicator suggests a known variable or transient: Gaia DR3 variability class, ASAS-SN variable type, VSX class, ZTF var type, TNS name, ALeRCE LC class, microlensing-catalog crossmatch, or SIMBAD type plausibly variable (very rough otype keyword match; see `vetting.py`).
#
# **`catalog_source`** (when present) comes from earlier filtering / periodic-catalog tagging, not from the live TAP vetting step.

# %%
def _has_str(col: str) -> pd.Series:
    if col not in df.columns:
        return pd.Series(False, index=df.index)
    s = df[col]
    if s.dtype == object or str(s.dtype).startswith('string'):
        return s.fillna('').astype(str).str.strip().ne('')
    return s.notna()

def _sim_simbad_var(series: pd.Series) -> pd.Series:
    """Loose analogue of vetting SIMBAD variable filter."""
    def one(x) -> bool:
        s = str(x).strip()
        if not s:
            return False
        if 'V*' in s:
            return True
        keys = ('EB*', 'YSO', 'SN', 'Nova', 'Catac', 'RR*', 'Cepheid', 'Mira', 'BYDra', 'RSCVn', 'Symbiotic',
                'ELL', 'Blazar', 'QSO', 'AGN', 'Em*', 'Be*', 'RS*', 'Orion')
        low = s.lower()
        return any(str(k).lower() in low for k in keys)
    return series.map(one)

contributors = {
    'gaia_var_class': _has_str('gaia_var_class'),
    'asassn_var_type': _has_str('asassn_var_type'),
    'vsx_class': _has_str('vsx_class'),
    'ztf_var_type': _has_str('ztf_var_type'),
    'tns_name': _has_str('tns_name'),
    'alerce_lc_class': _has_str('alerce_lc_class'),
}
if 'microlens_match' in df.columns:
    contributors['microlens_match'] = _booly(df['microlens_match']).fillna(False)
if 'nearest_simbad_object' in df.columns:
    contributors['has_simbad_name'] = _has_str('nearest_simbad_object')
if 'simbad_otype' in df.columns:
    contributors['simbad_var_like_otype'] = _sim_simbad_var(df['simbad_otype'].fillna('').astype(str))

con_df = pd.DataFrame(contributors)
print('Rows with each contributor (counts are not mutually exclusive):')
display(con_df.sum().sort_values(ascending=False).to_frame('n_rows'))
n_flags = con_df.sum(axis=1)
print('\nHow many contributor flags per candidate:')
display(n_flags.value_counts().sort_index().to_frame('n_candidates'))

if 'vetting_likely_known' in df.columns:
    vk = _booly(df['vetting_likely_known']).fillna(False)
    recon = con_df.any(axis=1)
    print('\nvetting_likely_known vs OR(contributors above):')
    display(pd.crosstab(vk, recon, margins=True, rownames=['vetting'], colnames=['recon_OR']))

if 'catalog_source' in df.columns:
    print('\ncatalog_source:')
    display(df['catalog_source'].fillna('').astype(str).replace('', '(empty)').value_counts(dropna=False).head(25).to_frame('n'))
# Out:
# Rows with each contributor (counts are not mutually exclusive):
#                        n_rows
# alerce_lc_class            44
# has_simbad_name            41
# vsx_class                  24
# gaia_var_class             22
# asassn_var_type            22
# simbad_var_like_otype      15
# ztf_var_type                0
# tns_name                    0
# microlens_match             0
# How many contributor flags per candidate:
#    n_candidates
# 0            27
# 1            29
# 2            33
# 3            19
# 4             4
# vetting_likely_known vs OR(contributors above):
# recon_OR  False  True  All
# vetting
# False        27    39   66
# True          0    46   46
# All          27    85  112
# catalog_source:
#                   n
# catalog_source
# (empty)         105
# asassn_var        5
# vsx               2

# %% [markdown]
# ## Young populations: moving groups, open clusters, star-forming regions, Hα
#
# **BANYAN Σ** — association with young moving groups / young associations (`banyan_best_assoc`, `banyan_field_prob`).
#
# **Open clusters** — `cluster_name` (+ distance/age when present).
#
# **SFR catalogue** — proximity to catalogued star-forming regions (`sfr_name`, `sfr_sep_arcmin`).
#
# **IPHAS** — emission-line / Hα-excess style flag (`iphas_ha_excess`) where the module ran.

# %%
char_status_cols = sorted([c for c in df.columns if c.startswith('char_status_')])
if char_status_cols:
    print('char_status_* summaries:')
    for c in char_status_cols:
        print(f'\n{c}')
        display(df[c].astype(str).value_counts(dropna=False).head(10).to_frame('n'))
else:
    print('No char_status_* columns.')

if {'banyan_best_assoc', 'banyan_field_prob'}.issubset(df.columns):
    assoc = df['banyan_best_assoc'].fillna('').astype(str).str.strip()
    named = assoc.ne('') & ~assoc.str.lower().isin({'nan', 'none', 'field'})
    print(f'\nBANYAN named association: {int(named.sum())} / {len(df)}')
    if named.any():
        cols = [KEY_ID, 'banyan_best_assoc', 'banyan_field_prob']
        cols += [c for c in ('mw_line_of_sight_region', 'gal_l_deg', 'gal_b_deg') if c in df.columns]
        display(df.loc[named, cols].head(25))
        bp = _num(df.loc[named, 'banyan_field_prob']).dropna()
        if len(bp) > 10:
            fig, ax = plt.subplots(figsize=(5.5, 3.2))
            ax.hist(bp, bins=20, color='tab:cyan', edgecolor='white')
            ax.set_xlabel('banyan_field_prob')
            ax.set_title('Field-star probability (named-assoc rows)')
            plt.tight_layout()
            plt.show()

if 'cluster_name' in df.columns:
    cn = df['cluster_name'].fillna('').astype(str).str.strip()
    in_cl = cn.ne('')
    print(f'\nOpen cluster match: {int(in_cl.sum())} / {len(df)}')
    if in_cl.any():
        display(cn[in_cl].value_counts().head(15).to_frame('n'))
        extra = [c for c in ('cluster_dist_pc', 'cluster_age_myr', 'cluster_membership_prob') if c in df.columns]
        display(df.loc[in_cl, [KEY_ID, 'cluster_name'] + extra].head(20))

if 'sfr_name' in df.columns:
    sn = df['sfr_name'].fillna('').astype(str).str.strip()
    near_sfr = sn.ne('')
    print(f'\nSFR catalogue proximity: {int(near_sfr.sum())} / {len(df)}')
    if near_sfr.any():
        ocols = [KEY_ID, 'sfr_name'] + (['sfr_sep_arcmin'] if 'sfr_sep_arcmin' in df.columns else [])
        ocols += [c for c in ('mw_line_of_sight_region', 'vetting_likely_known', 'fit_ok') if c in df.columns]
        tmp = df.loc[near_sfr, ocols].copy()
        if 'sfr_sep_arcmin' in tmp.columns:
            tmp = tmp.sort_values('sfr_sep_arcmin')
        display(tmp.head(25))
        display(sn[near_sfr].value_counts().head(12).to_frame('n'))

if 'iphas_ha_excess' in df.columns:
    raw = df['iphas_ha_excess']
    if raw.dtype == bool or str(raw.dtype) == 'boolean':
        hot = raw.fillna(False)
    else:
        hot = pd.to_numeric(raw, errors='coerce') > 0
        hot = hot | raw.astype(str).str.lower().isin({'true', '1', 't'})
    print(f'\nIPHAS Hα excess: {int(hot.fillna(False).sum())} / {len(df)}')
    if hot.any():
        sc = [KEY_ID] + [c for c in ('iphas_r_ha', 'iphas_r_i', 'simbad_otype', 'gaia_var_class', 'sfr_name') if c in df.columns]
        display(df.loc[hot.fillna(False), sc].head(20))
# Out:
# char_status_* summaries:
#
# char_status_allwise
#                        n
# char_status_allwise
# ok                   112
# char_status_apass
#                      n
# char_status_apass
# ok                 112
# char_status_banyan
#                       n
# char_status_banyan
# ok                  112
# char_status_clusters
#                         n
# char_status_clusters
# ok                    112
# char_status_dust
#                     n
# char_status_dust
# ok                112
# char_status_galex
#                      n
# char_status_galex
# ok                 112
# char_status_iphas
#                      n
# char_status_iphas
# ok                 112
# char_status_population
#                           n
# char_status_population
# ok                      112
# char_status_sfr
#                    n
# char_status_sfr
# ok               112
# char_status_starhorse
#                          n
# char_status_starhorse
# ok                     112
# char_status_unwise
#                       n
# char_status_unwise
# ok                  112
# char_status_yso
#                    n
# char_status_yso
# ok               112
# BANYAN named association: 0 / 112
#
# Open cluster match: 3 / 112
#               n
# cluster_name
# Pismis_20     1
# NGC_6834      1
# Bochum_11     1
#     candidate_id cluster_name  cluster_dist_pc  cluster_age_myr
# 26  566936268591    Pismis_20              NaN              NaN
# 41  146029437956     NGC_6834             3283          19.0546
# 62  618476320880    Bochum_11             2584          6.30958
# SFR catalogue proximity: 2 / 112
#     candidate_id             sfr_name mw_line_of_sight_region  vetting_likely_known  fit_ok
# 4    25771219762  Cygnus X (pos only)           galactic_disk                 False    True
# 39   85899644125             Cygnus X           galactic_disk                 False   False
#                      n
# sfr_name
# Cygnus X (pos only)  1
# Cygnus X             1
# IPHAS Hα excess: 0 / 112

# %% [markdown]
# ## Galactic line-of-sight × known-variable flag
# Bulge vs disk vs Cloud fields have different contamination from intrinsic variables and crowding.

# %%
if {'mw_line_of_sight_region', 'vetting_likely_known'}.issubset(df.columns):
    reg = df['mw_line_of_sight_region'].fillna('(missing)').astype(str)
    vk = _booly(df['vetting_likely_known']).fillna(False)
    print('Counts:')
    display(pd.crosstab(reg, vk, margins=True))
    print('Row % known (vetting_likely_known):')
    display((pd.crosstab(reg, vk, normalize='index') * 100).round(1))

if {'mw_line_of_sight_region', 'fit_ok'}.issubset(df.columns):
    reg = df['mw_line_of_sight_region'].fillna('(missing)').astype(str)
    fo = _booly(df['fit_ok']).fillna(False)
    display(fo.groupby(reg).mean().sort_values(ascending=False).to_frame('frac_fit_ok'))

if 'simbad_otype' in df.columns:
    pat = r'YSO|Orion|T Tau|Herbig|Em\*|PMS|Ae/Be|TTauri|CTTS|WTTS'
    yso_like = df['simbad_otype'].fillna('').astype(str).str.contains(pat, case=False, regex=True, na=False)
    print(f'\nSIMBAD otype YSO/PMS/emission-like (regex): {int(yso_like.sum())} / {len(df)}')
    if yso_like.any():
        cols = [c for c in (KEY_ID, 'simbad_otype', 'nearest_simbad_object', 'sfr_name', 'cluster_name',
                'vetting_likely_known', 'fit_ok', 'mw_line_of_sight_region') if c in df.columns]
        display(df.loc[yso_like, cols].head(25))
# Out:
# Counts:
# vetting_likely_known     False  True  All
# mw_line_of_sight_region
# LMC                          4     0    4
# SMC                          1     0    1
# galactic_bulge               3     4    7
# galactic_disk               57    40   97
# halo                         1     2    3
# All                         66    46  112
# Row % known (vetting_likely_known):
# vetting_likely_known     False  True
# mw_line_of_sight_region
# LMC                        100      0
# SMC                        100      0
# galactic_bulge            42.9   57.1
# galactic_disk             58.8   41.2
# halo                      33.3   66.7
#                          frac_fit_ok
# mw_line_of_sight_region
# galactic_bulge              0.285714
# galactic_disk               0.216495
# LMC                                0
# SMC                                0
# halo                               0
# SIMBAD otype YSO/PMS/emission-like (regex): 11 / 112
#      candidate_id simbad_otype nearest_simbad_object  sfr_name cluster_name  vetting_likely_known  fit_ok  \
# 20   163208971697          Em*          EM* GGA  159       NaN          NaN                  True   False
# 30   146029069479          Em*          EM* VES  945       NaN          NaN                 False   False
# 31   309238003696          Em*            [IC55b] 20       NaN          NaN                 False   False
# 34   489626666467          Em*       TYC 5992-1159-1       NaN          NaN                  True   False
# 39    85899644125          Em*           EM* AS  417  Cygnus X          NaN                 False   False
# 65   103080609465          Em*          EM* VES  869       NaN          NaN                  True   False
# 85   111669286812          Em*          EM* VES  596       NaN          NaN                  True   False
# 88    77310113008          Em*          EM* VES  115       NaN          NaN                 False   False
# 92   292058411251          Em*                   NaN       NaN          NaN                 False   False
# 99   377957176259          Em*                   NaN       NaN          NaN                 False   False
# 111   94490105040          Em*                   NaN       NaN          NaN                 False   False
#
#     mw_line_of_sight_region
# 20            galactic_disk
# 30            galactic_disk
# 31            galactic_disk
# 34            galactic_disk
# 39            galactic_disk
# 65            galactic_disk
# 85            galactic_disk
# 88            galactic_disk
# 92            galactic_disk
# 99            galactic_disk
# 111           galactic_disk

# %% [markdown]
# ## Dust & distance (optional characterize modules)
# `A_v_3d`, `ebv_3d` when **dustmaps** query ran. Distances from Gaia photometry / parallax or StarHorse when those columns exist.

# %%
dust_cols = [c for c in ('A_v_3d', 'ebv_3d', 'dust_sigma', 'dust_max_dist_kpc') if c in df.columns]
if dust_cols:
    display(df[dust_cols].apply(_num).describe().T)
    for c in dust_cols:
        x = _num(df[c]).replace([np.inf, -np.inf], np.nan).dropna()
        if len(x) > 3:
            fig, ax = plt.subplots(figsize=(4.8, 2.8))
            ax.hist(x, bins=28, color='peru', edgecolor='white')
            ax.set_title(c)
            plt.tight_layout()
            plt.show()
else:
    print('No 3D dust columns in this table.')

dist_like = [c for c in df.columns if c in ('distance_gspphot', 'parallax', 'gaia_parallax')]
dist_like += [c for c in df.columns if c.startswith('starhorse_') and df[c].dtype != object][:15]
dist_like = sorted(set(dist_like))
if dist_like:
    display(df[dist_like].apply(_num).describe().T.head(20))
# Out:
#                    count     mean       std       min       25%       50%       75%       max
# A_v_3d               112 0.104013  0.498237         0         0         0         0   3.42696
# ebv_3d                 6 0.626317  0.357696 0.0470151   0.52116   0.62392  0.808983   1.10547
# dust_sigma             6  0.04709 0.0178976 0.0317479 0.0353509 0.0427375 0.0497019 0.0804049
# dust_max_dist_kpc      6  9.41361   5.28983   3.54493    4.8615   9.73274   13.6607   15.2635
#                   count     mean     std      min     25%      50%      75%     max
# distance_gspphot      6  1778.96 956.164  729.878 1065.91  1754.81  2129.08 3344.14
# parallax             14 0.671346 0.45115 0.199129 0.43314 0.523374 0.647805 1.81986

# %% [markdown]
# ## Multiwavelength context (X-ray, mid-IR)
#
# **eROSITA** — `xray_det` / `xray_flux` / `xray_sep_arcsec` when the vetting crossmatch ran.
#
# **unWISE** — variability z-scores and flags when `characterize` queried unTimely (e.g. `unwise_w1_var`).

# %%
if 'xray_det' in df.columns:
    xd = _booly(df['xray_det']).fillna(False)
    print(f'eROSITA detection (xray_det): {int(xd.sum())} / {len(df)}')
    if xd.any() and 'xray_flux' in df.columns:
        fl = _num(df.loc[xd, 'xray_flux']).dropna()
        if len(fl):
            fig, ax = plt.subplots(figsize=(4.8, 2.8))
            ax.hist(np.log10(fl.clip(lower=1e-20)), bins=22, color='0.35', edgecolor='white')
            ax.set_xlabel('log10(xray_flux)')
            plt.title('eROSITA flux (detected rows)')
            plt.tight_layout()
            plt.show()
    show = [KEY_ID] + [c for c in ('xray_sep_arcsec', 'xray_flux', 'simbad_otype', 'mw_line_of_sight_region') if c in df.columns]
    if xd.any():
        display(df.loc[xd, show].head(20))

uw = [c for c in df.columns if c.startswith('unwise_') and c not in ('char_status_unwise',)]
if uw:
    print('\nunWISE-related columns (sample stats):')
    boolish = [c for c in uw if 'var' in c or c.endswith('_flag')]
    for c in boolish[:6]:
        if c not in df.columns:
            continue
        print(c, _booly(df[c]).fillna(False).value_counts(dropna=False).to_dict())
    numuw = [c for c in uw if c not in boolish][:8]
    if numuw:
        display(df[numuw].apply(_num).describe().T)
else:
    print('No unwise_* columns.')
# Out:
# eROSITA detection (xray_det): 2 / 112
#     candidate_id  xray_sep_arcsec   xray_flux simbad_otype mw_line_of_sight_region
# 71  300648519238            1.543 4.15646e-13          Sy*                    halo
# 98  369368437794            1.352 3.54712e-12          HXB                     SMC
# unWISE-related columns (sample stats):
# unwise_w1_var {False: 112}
#                   count  mean  std  min  25%  50%  75%  max
# unwise_w1             0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# unwise_w2             0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# unwise_w1_err         0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# unwise_w2_err         0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# unwise_w1_dered       0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# unwise_w2_dered       0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# unwise_w1_zscore      0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# unwise_w2_zscore      0   NaN  NaN  NaN  NaN  NaN  NaN  NaN

# %% [markdown]
# ## Environment overlay: SFR, cluster, or BANYAN (combined)
# Single mask for “interesting” **Galactic / youth** context when vetting microlensing-shaped events.

# %%
env_mask = pd.Series(False, index=df.index)
bits = {}
if 'sfr_name' in df.columns:
    bits['near_SFR'] = df['sfr_name'].fillna('').astype(str).str.strip().ne('')
if 'cluster_name' in df.columns:
    bits['open_cluster'] = df['cluster_name'].fillna('').astype(str).str.strip().ne('')
if 'banyan_best_assoc' in df.columns:
    a = df['banyan_best_assoc'].fillna('').astype(str).str.strip()
    bits['banyan_named'] = a.ne('') & ~a.str.lower().isin({'field', 'nan', 'none'})
for k, s in bits.items():
    env_mask = env_mask | s.fillna(False)

print(f'Any SFR / cluster / BANYAN hit: {int(env_mask.sum())} / {len(df)}')
if bits:
    display(pd.DataFrame({k: v.fillna(False) for k, v in bits.items()}).sum().to_frame('n'))

cols = [c for c in (KEY_ID, 'sfr_name', 'sfr_sep_arcmin', 'cluster_name', 'cluster_dist_pc',
        'banyan_best_assoc', 'banyan_field_prob', 'mw_line_of_sight_region', 'vetting_likely_known',
        'fit_ok', 'best_model', 'paczynski_reduced_chi2') if c in df.columns]
if env_mask.any():
    display(df.loc[env_mask, cols].head(45))
# Out:
# Any SFR / cluster / BANYAN hit: 5 / 112
#               n
# near_SFR      2
# open_cluster  3
# banyan_named  0
#     candidate_id             sfr_name cluster_name  cluster_dist_pc  banyan_best_assoc  banyan_field_prob  \
# 4    25771219762  Cygnus X (pos only)          NaN              NaN                NaN                NaN
# 26  566936268591                  NaN    Pismis_20              NaN                NaN                NaN
# 39   85899644125             Cygnus X          NaN              NaN                NaN                NaN
# 41  146029437956                  NaN     NGC_6834             3283                NaN                NaN
# 62  618476320880                  NaN    Bochum_11             2584                NaN                NaN
#
#    mw_line_of_sight_region  vetting_likely_known  fit_ok best_model  paczynski_reduced_chi2
# 4            galactic_disk                 False    True  paczynski                 4.48232
# 26           galactic_disk                 False   False       fred                 25.2822
# 39           galactic_disk                 False   False  paczynski                 10.0562
# 41           galactic_disk                  True   False       fred                 15.0779
# 62           galactic_disk                 False   False       fred                 8.32822

# %% [markdown]
# ## Sky & Galactic coordinates

# %%
if {"ra_deg", "dec_deg"}.issubset(df.columns):
    ra, dec = _num(df["ra_deg"]), _num(df["dec_deg"])
    okc = np.isfinite(ra.to_numpy()) & np.isfinite(dec.to_numpy())
    color = None
    if "fit_ok" in df.columns:
        fk = _booly(df["fit_ok"]).fillna(False)
        color = np.where(fk.to_numpy()[okc], "tab:blue", "tab:red")
    fig, ax = plt.subplots(figsize=(9, 4.5))
    ax.scatter(ra.to_numpy()[okc], dec.to_numpy()[okc], c=color, s=12, alpha=0.55)
    if color is not None:
        ax.legend(handles=[
            Line2D([0], [0], marker="o", color="w", markerfacecolor="tab:blue", markersize=8, label="fit_ok"),
            Line2D([0], [0], marker="o", color="w", markerfacecolor="tab:red", markersize=8, label="not fit_ok"),
        ])
    ax.set_xlabel("RA (deg)")
    ax.set_ylabel("Dec (deg)")
    ax.set_title("Equatorial distribution")
    ax.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()

if {"mw_line_of_sight_region", "fit_ok"}.issubset(df.columns):
    reg = df["mw_line_of_sight_region"].fillna("(na)").astype(str)
    fk = _booly(df["fit_ok"]).fillna(False)
    ct = pd.crosstab(reg, fk)
    display(ct)
    if len(ct) and ct.size:
        fig, ax = plt.subplots(figsize=(max(6, 0.35 * len(ct)), 4))
        ct.plot(kind="barh", stacked=True, ax=ax, color=["tab:red", "tab:blue"])
        ax.set_xlabel("count")
        ax.legend(["not fit_ok", "fit_ok"])
        plt.title("fit_ok vs Milky-Way region")
        plt.tight_layout()
        plt.show()

if {"gal_l_deg", "gal_b_deg"}.issubset(df.columns):
    gl, gb = _num(df["gal_l_deg"]), _num(df["gal_b_deg"])
    m = gl.notna() & gb.notna()
    if m.sum():
        fig, ax = plt.subplots(figsize=(7.5, 4))
        ax.scatter(gl[m], gb[m], s=10, alpha=0.45, c="0.35")
        ax.set_xlabel("Galactic ℓ (deg)")
        ax.set_ylabel("Galactic b (deg)")
        plt.title("Galactic coordinates")
        plt.tight_layout()
        plt.show()
# Out:
# fit_ok                   False  True
# mw_line_of_sight_region
# LMC                          4      0
# SMC                          1      0
# galactic_bulge               5      2
# galactic_disk               76     21
# halo                         3      0

# %% [markdown]
# ## Missingness (grouped)

# %%
groups = {
    "parallax": [c for c in df.columns if c.startswith("parallax_")],
    "external+surveys": [c for c in df.columns if c.startswith(("external_", "ogle_", "kmtnet_", "moa_"))],
    "delta_bic": [c for c in df.columns if c.startswith("delta_bic") or c.startswith("log10_delta_bic")],
}

for gname, cols in groups.items():
    cols = [c for c in cols if c in df.columns]
    if len(cols) < 2:
        continue
    fr = df[cols].isna().mean().sort_values(ascending=False)
    fig, ax = plt.subplots(figsize=(8, max(2.5, 0.2 * len(fr))))
    ax.barh(fr.index[::-1], fr.values[::-1], color="slategray")
    ax.set_xlim(0, 1)
    ax.set_xlabel("fraction NA")
    ax.set_title(f"Missing fraction: {gname}")
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## fit_warning tokens & pairs

# %%
if "fit_warning" not in df.columns:
    print("no fit_warning")
else:
    raw = df["fit_warning"].fillna("").astype(str)
    nn = raw.str.len() > 0
    print(f"non-empty fit_warning: {int(nn.sum())} / {len(df)}")
    tok = raw.str.split(",").explode().str.strip().replace("", pd.NA).dropna()
    display(tok.value_counts().head(40).to_frame("n"))
    pair_counts = {}
    for s in raw.loc[nn]:
        toks = sorted(set(t.strip() for t in s.split(",") if t.strip()))
        for a, b in combinations(toks, 2):
            pair_counts[(a, b)] = pair_counts.get((a, b), 0) + 1
    if pair_counts:
        top = sorted(pair_counts.items(), key=lambda kv: -kv[1])[:25]
        display(pd.DataFrame([(a, b, n) for (a, b), n in top], columns=["warn_a", "warn_b", "n"]))
# Out:
# non-empty fit_warning: 91 / 112
#                                    n
# fit_warning
# high_reduced_chi2                 75
# significant_fred_preferred        57
# event_coverage_below_recommended  14
# t0_near_bound                      4
# low_event_coverage                 3
# insufficient_shoulders             3
# A0_near_bound                      1
#                               warn_a                      warn_b   n
# 0                  high_reduced_chi2  significant_fred_preferred  45
# 1   event_coverage_below_recommended           high_reduced_chi2   9
# 2   event_coverage_below_recommended  significant_fred_preferred   5
# 3   event_coverage_below_recommended               t0_near_bound   4
# 4   event_coverage_below_recommended      insufficient_shoulders   3
# 5                  high_reduced_chi2               t0_near_bound   3
# 6                  high_reduced_chi2          low_event_coverage   2
# 7                 low_event_coverage  significant_fred_preferred   2
# 8                  high_reduced_chi2      insufficient_shoulders   2
# 9             insufficient_shoulders               t0_near_bound   2
# 10            insufficient_shoulders  significant_fred_preferred   1
# 11        significant_fred_preferred               t0_near_bound   1
# 12                     A0_near_bound           high_reduced_chi2   1
# 13                     A0_near_bound          low_event_coverage   1

# %% [markdown]
# ## Ranked slices

# %%
base_cols = [
    c for c in (
        KEY_ID, "best_model", "selection_mode", "fit_ok", "paczynski_reduced_chi2",
        "fit_reduced_chi2", "reported_tE_days", "delta_bic_vs_flat", "mw_line_of_sight_region",
    ) if c in df.columns
]

if "paczynski_reduced_chi2" in df.columns and len(df):
    idx = _num(df["paczynski_reduced_chi2"]).nlargest(min(15, len(df))).index
    print("Highest paczynski_reduced_chi2:")
    display(df.loc[idx, base_cols])

if "delta_bic_vs_flat" in df.columns and len(df):
    idx = _num(df["delta_bic_vs_flat"]).nlargest(min(15, len(df))).index
    print("\nLargest delta_bic_vs_flat:")
    display(df.loc[idx, base_cols])

if {"fit_ok", "vetting_likely_known"}.issubset(df.columns):
    mask = _booly(df["fit_ok"]).fillna(False) & ~_booly(df["vetting_likely_known"]).fillna(False)
    print(f"\nfit_ok & not vetting_likely_known: {int(mask.sum())}")
    if mask.any():
        display(df.loc[mask, base_cols].head(30))
# Out:
# Highest paczynski_reduced_chi2:
#      candidate_id best_model         selection_mode  fit_ok  paczynski_reduced_chi2  fit_reduced_chi2  \
# 48   257698235806       fred  significant_alt_model   False                 60.9144           58.8756
# 71   300648519238       fred  significant_alt_model   False                 58.7592           24.6734
# 109  575526714343       fred  significant_alt_model   False                 52.8744           23.2863
# 59   558345766156  paczynski     fallback_paczynski   False                 46.0435           46.0435
# 40   103080402985       fred  significant_alt_model   False                 35.6663           24.5973
# 1    120259784233  paczynski     fallback_paczynski   False                 28.3005           28.3005
# 57   549756255044  paczynski     fallback_paczynski   False                 28.1294           28.1294
# 55   523987126282       fred  significant_alt_model   False                 27.6766            26.477
# 56   541166874049       fred  significant_alt_model   False                 25.6932           18.7555
# 26   566936268591       fred  significant_alt_model   False                 25.2822           24.7719
# 80   592705976655  paczynski     fallback_paczynski   False                  25.257            25.257
# 61   584116581240  paczynski     fallback_paczynski   False                 25.0634           25.0634
# 12   575525833425       fred  significant_alt_model   False                  23.618           21.7668
# 67   146028946908       fred  significant_alt_model   False                 19.3758           18.3572
# 30   146029069479       fred  significant_alt_model   False                 17.0433           12.5596
#
#      reported_tE_days  delta_bic_vs_flat mw_line_of_sight_region
# 48                NaN            96874.8           galactic_disk
# 71                NaN            83404.4                    halo
# 109               NaN            29399.7           galactic_disk
# 59                NaN            4041.21           galactic_disk
# 40                NaN            4812.31           galactic_disk
# 1                 NaN             239718           galactic_disk
# 57                NaN             253442                     LMC
# 55                NaN            40547.3           galactic_disk
# 56                NaN            21536.6                    halo
# 26                NaN              20052           galactic_disk
# 80                NaN            5588.61           galactic_disk
# 61                NaN            3510.94           galactic_disk
# 12                NaN             509734           galactic_disk
# 67                NaN            23867.8           galactic_disk
# 30                NaN            2696.69           galactic_disk
# Largest delta_bic_vs_flat:
#     candidate_id best_model         selection_mode  fit_ok  paczynski_reduced_chi2  fit_reduced_chi2  \
# 12  575525833425       fred  significant_alt_model   False                  23.618           21.7668
# 57  549756255044  paczynski     fallback_paczynski   False                 28.1294           28.1294
# 1   120259784233  paczynski     fallback_paczynski   False                 28.3005           28.3005
# 94  317828552480       fred  significant_alt_model   False                   9.741           8.59377
# 48  257698235806       fred  significant_alt_model   False                 60.9144           58.8756
# 71  300648519238       fred  significant_alt_model   False                 58.7592           24.6734
# 21  188979391597       fred  significant_alt_model   False                 8.63309           7.30776
# 29  120260181420  paczynski     fallback_paczynski   False                  7.1605            7.1605
# 79  575526671022       fred  significant_alt_model   False                 8.64032           7.69084
# 74  386547890812       fred  significant_alt_model   False                 10.0471           9.16399
# 41  146029437956       fred  significant_alt_model   False                 15.0779           12.3483
# 13  609886176748  paczynski     fallback_paczynski   False                 7.73123           7.73123
# 35  506806257773  paczynski     fallback_paczynski   False                 9.16798           9.16798
# 63  635655307328  paczynski     fallback_paczynski   False                 7.33021           7.33021
# 47  249108525273       fred  significant_alt_model   False                 9.80437           9.42353
#
#     reported_tE_days  delta_bic_vs_flat mw_line_of_sight_region
# 12               NaN             509734           galactic_disk
# 57               NaN             253442                     LMC
# 1                NaN             239718           galactic_disk
# 94               NaN             133561                     LMC
# 48               NaN            96874.8           galactic_disk
# 71               NaN            83404.4                    halo
# 21               NaN            81197.8           galactic_disk
# 29               NaN            59307.7           galactic_disk
# 79               NaN            58511.4          galactic_bulge
# 74               NaN            52876.9           galactic_disk
# 41               NaN            52348.3           galactic_disk
# 13               NaN            47427.1           galactic_disk
# 35               NaN            46806.3           galactic_disk
# 63               NaN            45459.9           galactic_disk
# 47               NaN            42127.2           galactic_disk
# fit_ok & not vetting_likely_known: 14
#      candidate_id best_model selection_mode  fit_ok  paczynski_reduced_chi2  fit_reduced_chi2  reported_tE_days  \
# 2    171799355659  paczynski   paczynski_qc    True                 3.94957           3.94957           50.7272
# 4     25771219762  paczynski   paczynski_qc    True                 4.48232           4.48232           142.868
# 7    472447489028  paczynski   paczynski_qc    True                 4.21688           4.21688            120.58
# 9    489626721133  paczynski   paczynski_qc    True                 4.85965           4.85965           105.028
# 10   541166175153  paczynski   paczynski_qc    True                 3.72436           3.72436           124.105
# 11   566936418537  paczynski   paczynski_qc    True                 2.71633           2.71633           54.1043
# 14   618475317371  paczynski   paczynski_qc    True                  3.7438            3.7438           70.6784
# 27   566936418698  paczynski   paczynski_qc    True                 4.63522           4.63522           42.6821
# 37   584116544153  paczynski   paczynski_qc    True                 2.24695           2.24695            78.149
# 44   171799069048  paczynski   paczynski_qc    True                 4.36366           4.36366           103.976
# 51   326418144856  paczynski   paczynski_qc    True                 4.11756           4.11756           225.178
# 64    77310492274  paczynski   paczynski_qc    True                 4.93868           4.93868           94.1793
# 100  395137918765  paczynski   paczynski_qc    True                 4.33048           4.33048           18.5037
# 110   77310672808  paczynski   paczynski_qc    True                 4.07815           4.07815           151.853
#
#      delta_bic_vs_flat mw_line_of_sight_region
# 2              21925.4           galactic_disk
# 4                31411           galactic_disk
# 7              17185.5          galactic_bulge
# 9              19488.3           galactic_disk
# 10             28022.5           galactic_disk
# 11             18998.8           galactic_disk
# 14             14565.2           galactic_disk
# 27             8810.31           galactic_disk
# 37             7909.77           galactic_disk
# 44             6854.87           galactic_disk
# 51              6322.8           galactic_disk
# 64             7203.64           galactic_disk
# 100            13157.9          galactic_bulge
# 110            5346.49           galactic_disk

# %% [markdown]
# ## Optional: slim parquet

# %%
SLIM = [c for c in (
    KEY_ID, "asas_sn_id", "lc_path", "band_used", "best_model", "selection_mode", "fit_ok",
    "reported_tE_days", "raw_paczynski_tE_days", "paczynski_reduced_chi2", "fit_reduced_chi2",
    "delta_bic_vs_flat", "delta_bic_vs_gaussian", "delta_bic_vs_fred", "fit_warning",
    "ra_deg", "dec_deg", "mw_line_of_sight_region", "vetting_likely_known", "simbad_otype",
    "parallax_status", "external_known_microlens",
) if c in df.columns]
out = CSV_PATH.with_name(CSV_PATH.stem + "_slim.parquet")
# df[SLIM].to_parquet(out, index=False); print("Wrote", out)
print("Uncomment to_parquet in cell to write:", out)
# Out:
# Uncomment to_parquet in cell to write: /home/calder/code/malca/output/microlensing/microlensing_results_20260325_131310_slim.parquet
